# %%
import pandas as pd

# %%
df = pd.read_csv('all.csv')
df
# Out:
#            AREA                               AREA_TITLE PRIM_STATE   NAICS  \
# 0            99                                     U.S.         US  813200
# 1            38                             North Dakota         ND       0
# 2            29                                 Missouri         MO       0
# 3         40140     Riverside-San Bernardino-Ontario- CA         CA       0
# 4         40900  Sacramento--Roseville--Arden-Arcade- CA         CA       0
# ...         ...                                      ...        ...     ...
# 409401       72                              Puerto Rico         PR       0
# 409402    25620                          Hattiesburg- MS         MS       0
# 409403    11500         Anniston-Oxford-Jacksonville- AL         AL       0
# 409404  4000002  Northwest Oklahoma nonmetropolitan area         OK       0
# 409405   100001   Northwest Alabama nonmetropolitan area         AL       0
#
# ...

# %%
Alabama = df[df['PRIM_STATE']=="AL"]

# %%
state = input()
# Out:
# NY

# %%
state
# Out:
# 'NY'

# %%
state_df = df[df['PRIM_STATE']=='{}'.format(state)]

# %%
state_df=state_df.dropna(subset=['H_MEAN','H_MEDIAN'])

# %%
state_df
# Out:
#            AREA                                      AREA_TITLE PRIM_STATE  \
# 20945     15380           Buffalo-Cheektowaga-Niagara Falls- NY         NY
# 20994        36                                        New York         NY
# 21086   3600001  Capital/Northern New York nonmetropolitan area         NY
# 21164     35620           New York-Newark-Jersey City- NY-NJ-PA         NY
# 21680     35620           New York-Newark-Jersey City- NY-NJ-PA         NY
# ...         ...                                             ...        ...
# 393865    40380                                   Rochester- NY         NY
# 394304    13780                                  Binghamton- NY         NY
# 394730    48060                         Watertown-Fort Drum- NY         NY
# 396767  3600004         Southwest New York nonmetropolitan area         NY
# 397304    13780                                  Binghamton- NY         NY
#
# ...
